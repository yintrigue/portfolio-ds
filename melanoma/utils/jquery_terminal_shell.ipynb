# %% [markdown]
# See jQuery Terminal's [Features](https://terminal.jcubic.pl/)

# %%
# mount google drive
from google.colab import files
from google.colab import drive
import os
drive.mount('/content/gdrive')

# set current directory to git repo
# %cd /content/gdrive/My Drive/melanoma/
# %ls -la -h
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/.shortcut-targets-by-id/1-LIldeX9kC-BgVUenXNi_6IJ_aZrGmD5/melanoma
# total 26K
# drwx------ 2 root root 4.0K Jul  1 06:28 deliverables/
# drwx------ 2 root root 4.0K Jul  1 06:09 .git/
# -rw------- 1 root root 1.8K Jul 13 23:14 .gitignore
# drwx------ 2 root root 4.0K Jul  1 06:28 .ipynb_checkpoints/
# drwx------ 2 root root 4.0K Jul 15 00:56 _temp/
# drwx------ 2 root root 4.0K Jul  1 06:09 tim/
# drwx------ 2 root root 4.0K Jul  3 04:29 utils/

# %%
# set up GitHub access
from getpass import getpass
# !git config --global user.email "chentim@berkeley.edu"
# !git config --global user.name "yintrigue"
# !git config --global credential.username "yintrigue"
password = getpass('Password:')
# !git remote set-url origin https://yintrigue:$password@github.com/yintrigue/melanoma.git
# Out:
# Password:··········

# %%
# initialize JSON terminal
from IPython.display import JSON
from google.colab import output
from subprocess import getoutput
import os
def shell(command):
    if command.startswith('cd'):
        path = command.strip().split(maxsplit=1)[1]
        os.chdir(path)
        return JSON([''])
    return JSON([getoutput(command)])
output.register_callback('shell', shell)

# %%
#@title Colab Shell
# %%html
<div id=term_demo></div>
<script src="https://code.jquery.com/jquery-latest.js"></script>
<script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
<link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
<script>
  $('#term_demo').terminal(async function(command) {
      if (command !== '') {
          try {
              let res = await google.colab.kernel.invokeFunction('shell', [command])
              let out = res.data['application/json'][0]
              this.echo(new String(out))
          } catch(e) {
              this.error(new String(e));
          }
      } else {
          this.echo('');
      }
  }, {
      greetings: 'Welcome to Colab Shell',
      name: 'colab_demo',
      height: 250,
      prompt: 'colab > '
  });
# Out:
# <div id=term_demo></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#   $('#term_demo').terminal(async function(command) {
#       if (command !== '') {
#           try {
#               let res = await google.colab.kernel.invokeFunction('shell', [command])
#               let out = res.data['application/json'][0]
#               this.echo(new String(out))
#           } catch(e) {
#               this.error(new String(e));
#           }
#       } else {
#           this.echo('');
#       }
#   }, {
#       greetings: 'Welcome to Colab Shell',
#       name: 'colab_demo',
#       height: 250,
#       prompt: 'colab > '
#   });
